# %%
# Guide: https://mesa.readthedocs.io/en/main/tutorials/intro_tutorial.html

# %%
import mesa
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %pwd
# Out:
# 'D:\\GitHub\\Study_Projects\\Thesis'

# %%
from tutorial_model.money_model import MoneyModel

# %%
# create an instance of MoneyModel with 10 agents
starter_model = MoneyModel(50, 10, 10)
# advance model by i steps with agents stepping in random order
for i in range(200):
    starter_model.step()

# %%
gini = starter_model.datacollector.get_model_vars_dataframe()
gini.plot();
# Out:
# <Axes: >

# %%
agent_wealth = starter_model.datacollector.get_agent_vars_dataframe()
agent_wealth.head(1000)
# Out:
#               Wealth
# Step AgentID
# 0    0             1
#      1             1
#      2             1
#      3             1
#      4             1
# ...              ...
# 19   45            0
#      46            0
#      47            4
#      48            0
#      49            0
#
# [1000 rows x 1 columns]
